# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("Top 50 Fast-Food Chains in USA.csv")

# %%
data.head(15)
# Out:
#     Fast-Food Chains  U.S. Systemwide Sales (Millions - U.S Dollars)  \
# 0             Arby’s                                            4462
# 1     Baskin-Robbins                                             686
# 2          Bojangles                                            1485
# 3        Burger King                                           10033
# 4         Carl’s Jr.                                            1560
# 5   Checkers/Rally’s                                             931
# 6        Chick-fil-A                                           16700
# 7           Chipotle                                            7547
# 8   Church’s Chicken                                             776
# 9           Culver’s                                            2489
# 10       Dairy Queen                                            4494
# 11          Del Taco                                             931
# 12          Domino's                                            8641
# 13           Dunkin'                                           10416
# 14     El Pollo Loco                                             973
#
#     Average Sales per Unit (Thousands - U.S Dollars)  Franchised Stores  \
# 0                                               1309               2293
# 1                                                296               2317
# 2                                               1924                496
# 3                                               1470               7054
# 4                                               1400               1011
# 5                                               1145                568
# 6                                               6100               2650
# 7                                               2641                  0
# 8                                                870                731
# 9                                               3099                831
# 10                                              1036               4337
# 11                                              1551                306
# 12                                              1317               6185
# 13                                              1127               9244
# 14                                              2000                292
#
#     Company Stores  2021 Total Units  Total Change in Units from 2020
# 0             1116              3409                               40
# 1                0              2317                              102
# 2              277               773                               15
# 3               51              7105                               24
# 4               47              1058                              -21
# 5              266               834                              -13
# 6               82              2732                              155
# 7             2966              2966                              198
# 8              161               892                              -13
# 9                6               837                               55
# 10               2              4339                              -22
# 11             294               600                                4
# 12             375              6560                              205
# 13               0              9244                              161
# 14             189               481                                1

# %%
data.isnull().sum()
# Out:
# Fast-Food Chains                                    0
# U.S. Systemwide Sales (Millions - U.S Dollars)      0
# Average Sales per Unit (Thousands - U.S Dollars)    0
# Franchised Stores                                   0
# Company Stores                                      0
# 2021 Total Units                                    0
# Total Change in Units from 2020                     0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Fast-Food Chains                                  50 non-null     object
#  1   U.S. Systemwide Sales (Millions - U.S Dollars)    50 non-null     int64
#  2   Average Sales per Unit (Thousands - U.S Dollars)  50 non-null     int64
#  3   Franchised Stores                                 50 non-null     int64
#  4   Company Stores                                    50 non-null     int64
#  5   2021 Total Units                                  50 non-null     int64
#  6   Total Change in Units from 2020                   50 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 2.9+ KB

# %%
data = data.astype({col: 'int32' for col in data.select_dtypes('int64').columns})

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Fast-Food Chains                                  50 non-null     object
#  1   U.S. Systemwide Sales (Millions - U.S Dollars)    50 non-null     int32
#  2   Average Sales per Unit (Thousands - U.S Dollars)  50 non-null     int32
#  3   Franchised Stores                                 50 non-null     int32
#  4   Company Stores                                    50 non-null     int32
#  5   2021 Total Units                                  50 non-null     int32
#  6   Total Change in Units from 2020                   50 non-null     int32
# dtypes: int32(6), object(1)
# memory usage: 1.7+ KB
